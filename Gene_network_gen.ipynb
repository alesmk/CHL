# %% [markdown]
# Andiamo a prendere i vari file che e andiamo a vedere i valori della

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

DataSetTiroide=pd.read_csv('data_mrna_seq_v2_rsem_zscores_ref_all_samples_Tiroide.txt', sep='\t')

#TCGA-4C-A93U-01

DataSetTiroide2=DataSetTiroide.drop(columns='Hugo_Symbol',axis=1)

Paziente=DataSetTiroide2['TCGA-BJ-A0ZB-01']

print(DataSetTiroide2)
# Out:
#        Entrez_Gene_Id  TCGA-4C-A93U-01  TCGA-BJ-A0YZ-01  TCGA-BJ-A0Z0-01  \
# 0           100130426          -3.9624          -3.9624          -3.9624
# 1           100133144          -0.9789           1.1786           0.1962
# 2           100134869          -3.6892          -1.5617          -1.0676
# 3               10357          -0.0047           0.1338           0.8272
# 4               10431          -1.2387           2.9145           0.2349
# ...               ...              ...              ...              ...
# 20526          440590          -0.6843           0.3140           1.0698
# 20527           79699           0.8509          -1.1667           1.4279
# 20528            7791           0.7774          -0.5895          -2.0157
# 20529           23140          -1.1984           0.8134           1.1253
# 20530           26009          -0.8355          -0.3116           1.7016
#
#        TCGA-BJ-A0Z2-01  TCGA-BJ-A0Z3-01  TCGA-BJ-A0Z5-01  TCGA-BJ-A0Z9-01  \
# ...

# %% [markdown]
# Si prende in considerazione un solo paziente adesso  Entrez_Gene_Id','TCGA-BJ-A0ZB-01'

# %%
Paziente=DataSetTiroide2.loc[:2]

print(Paziente)
# Out:
#    Entrez_Gene_Id  TCGA-4C-A93U-01  TCGA-BJ-A0YZ-01  TCGA-BJ-A0Z0-01  \
# 0       100130426          -3.9624          -3.9624          -3.9624
# 1       100133144          -0.9789           1.1786           0.1962
# 2       100134869          -3.6892          -1.5617          -1.0676
#
#    TCGA-BJ-A0Z2-01  TCGA-BJ-A0Z3-01  TCGA-BJ-A0Z5-01  TCGA-BJ-A0Z9-01  \
# 0          -3.9624          -3.9624          -3.9624          -3.9624
# 1           1.1425          -0.8118          -2.5189          -0.1235
# 2           1.1388          -0.1618           0.0549          -0.1211
#
#    TCGA-BJ-A0ZA-01  TCGA-BJ-A0ZB-01  ...  TCGA-KS-A4ID-01  TCGA-L6-A4EP-01  \
# 0          -3.9624          -3.9624  ...          -3.9624          -3.9624
# 1           0.8396           0.7139  ...           1.0462          -2.6659
# 2          -1.7182          -0.1577  ...           0.1189           0.6642
#
#    TCGA-L6-A4EQ-01  TCGA-L6-A4ET-01  TCGA-L6-A4EU-01  TCGA-MK-A4N6-01  \
# ...
